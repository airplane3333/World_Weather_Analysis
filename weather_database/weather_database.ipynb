# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random as rd
from citipy import citipy
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
#create a set of random latitudes and longitude conbinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
#print the city count to confirm sufficient count
len(cities)
# Out:
# 768

# %%
import requests as req
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
 #create endpoint URL with each city

city_url = url + "&q=" + "phoenix"
#print(city_url)
city_weather = req.get(city_url).json()

city_weather
# Out:
# {'coord': {'lon': -112.074, 'lat': 33.4484},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02n'}],
#  'base': 'stations',
#  'main': {'temp': 71.85,
#   'feels_like': 69.87,
#   'temp_min': 68.14,
#   'temp_max': 74.77,
#   'pressure': 1013,
#   'humidity': 24},
#  'visibility': 10000,
#  'wind': {'speed': 5.99, 'deg': 253, 'gust': 11.99},
#  'clouds': {'all': 20},
#  'dt': 1635296970,
#  'sys': {'type': 2,
#   'id': 2008537,
#   'country': 'US',
#   'sunrise': 1635255719,
#   'sunset': 1635295333},
#  'timezone': -25200,
#  'id': 5308655,
#  'name': 'Phoenix',
#  'cod': 200}

# %%
city_lat = city_weather["coord"]["lat"],
city_lng = city_weather["coord"]["lon"],
city_max_temp = city_weather["main"]["temp_max"],
city_humidity = city_weather["main"]["humidity"],
city_clouds = city_weather["clouds"]["all"],
city_wind = city_weather["wind"]["speed"],
city_country = city_weather["sys"]["country"],
city_desc = city_weather["weather"][0]["description"]

print(city_lat ,city_lng ,city_max_temp ,city_humidity ,city_clouds ,city_wind ,city_country ,city_desc)
# Out:
# (33.4484,) (-112.074,) (75.76,) (24,) (20,) (5.99,) ('US',) few clouds

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval      ")
print("------------------------------")

#create counters
record_count = 1
set_count = 1

#create a loop that goes through the cities list 
for i, city in enumerate(cities):
    
    #group cities int sets of 50 for loggin purposes
    if (i % 50 == 0 and i >= 50):
        
        set_count += 1
        record_count = 1
        
    #create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    #print(city_url)
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = req.get(city_url).json()
        #print(city_weather)
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_desc,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | yellowknife
# Processing Record 7 of Set 1 | tarakan
# Processing Record 8 of Set 1 | dunedin
# Processing Record 9 of Set 1 | santo domingo
# Processing Record 10 of Set 1 | ostrow wielkopolski
# Processing Record 11 of Set 1 | port alfred
# Processing Record 12 of Set 1 | krasnyy yar
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | nikolskoye
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | dikson
# Processing Record 18 of Set 1 | upernavik
# Processing Record 19 of Set 1 | tuktoyaktuk
# Processing Record 20 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 1 | carnarvon
# Processing Record 24 of Set 1 | kodiak
# Processing Record 25 of Set 1 | khani
# Processing Record 26 of Set 1 | albanel
# Processing Record 27 of Set 1 | victoria
# Processing Record 28 of Set 1 | bredasdorp
# Processing Record 29 of Set 1 | bambous virieux
# Processing Record 30 of Set 1 | torbay
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | dondo
# Processing Record 33 of Set 1 | jamestown
# Processing Record 34 of Set 1 | saint-francois
# Processing Record 35 of Set 1 | elat
# Processing Record 36 of Set 1 | tasiilaq
# Processing Record 37 of Set 1 | chuy
# Processing Record 38 of Set 1 | bethel
# Processing Record 39 of Set 1 | aloleng
# Processing Record 40 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 1 | port lincoln
# Processing Record 42 of Set 1 | airai
# Processing Record 43 of Set 1 | alofi
# Processing Record 44 of Set 1 | mandalgovi
# Processing Record 45 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 1 | sao filipe
# Processing Record 47 of Set 1 | maarianhamina
# Processing Record 48 of Set 1 | qaanaaq
# Processing Record 49 of Set 1 | pangkalanbuun
# Processing Record 50 of Set 1 | butaritari
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | amuntai
# Processing Record 3 of Set 2 | autazes
# Processing Record 4 of Set 2 | sechelt
# Processing Record 5 of Set 2 | bengkulu
# Processing Record 6 of Set 2 | hilo
# Processing Record 7 of Set 2 | aswan
# Processing Record 8 of Set 2 | wadi musa
# Processing Record 9 of Set 2 | funtua
# Processing Record 10 of Set 2 | paamiut
# Processing Record 11 of Set 2 | cape town
# Processing Record 12 of Set 2 | lasa
# Processing Record 13 of Set 2 | chihuahua
# Processing Record 14 of Set 2 | coffs harbour
# Processing Record 15 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | urumqi
# Processing Record 18 of Set 2 | kaitangata
# Processing Record 19 of Set 2 | hobart
# Processing Record 20 of Set 2 | campbell river
# Processing Record 21 of Set 2 | khatanga
# Processing Record 22 of Set 2 | rorvik
# Processing Record 23 of Set 2 | yanam
# Processing Record 24 of Set 2 | fortuna
# Processing Record 25 of Set 2 | biltine
# Processing Record 26 of Set 2 | wum
# Processing Record 27 of Set 2 | vanimo
# Processing Record 28 of Set 2 | naze
# Processing Record 29 of Set 2 | cockburn town
# Processing Record 30 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 31 of Set 2 | chenghai
# Processing Record 32 of Set 2 | cagliliog
# Processing Record 33 of Set 2 | saskylakh
# Processing Record 34 of Set 2 | chumikan
# Processing Record 35 of Set 2 | karratha
# Processing Record 36 of Set 2 | alice springs
# Processing Record 37 of Set 2 | puerto ayora
# Processing Record 38 of Set 2 | nouadhibou
# Processing Record 39 of Set 2 | phan thiet
# Processing Record 40 of Set 2 | luganville
# Processing Record 41 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 2 | cherskiy
# Processing Record 43 of Set 2 | xadani
# City not found. Skipping...
# Processing Record 44 of Set 2 | labuhan
# Processing Record 45 of Set 2 | sataua
# City not found. Skipping...
# Processing Record 46 of Set 2 | lebu
# Processing Record 47 of Set 2 | beringovskiy
# Processing Record 48 of Set 2 | ternate
# Processing Record 49 of Set 2 | ridgecrest
# Processing Record 50 of Set 2 | saint-philippe
# Processing Record 1 of Set 3 | leningradskiy
# Processing Record 2 of Set 3 | coahuayana
# Processing Record 3 of Set 3 | haysville
# Processing Record 4 of Set 3 | viedma
# Processing Record 5 of Set 3 | barrow
# Processing Record 6 of Set 3 | havoysund
# Processing Record 7 of Set 3 | mahon
# Processing Record 8 of Set 3 | broome
# Processing Record 9 of Set 3 | eldikan
# City not found. Skipping...
# Processing Record 10 of Set 3 | san patricio
# Processing Record 11 of Set 3 | wattegama
# Processing Record 12 of Set 3 | port elizabeth
# Processing Record 13 of Set 3 | mangai
# Processing Record 14 of Set 3 | atasu
# Processing Record 15 of Set 3 | provideniya
# Processing Record 16 of Set 3 | vaini
# Processing Record 17 of Set 3 | kaeo
# Processing Record 18 of Set 3 | gigmoto
# Processing Record 19 of Set 3 | oriximina
# Processing Record 20 of Set 3 | vila franca do campo
# Processing Record 21 of Set 3 | east london
# Processing Record 22 of Set 3 | dudinka
# Processing Record 23 of Set 3 | kloulklubed
# Processing Record 24 of Set 3 | hithadhoo
# Processing Record 25 of Set 3 | welkom
# Processing Record 26 of Set 3 | kavieng
# Processing Record 27 of Set 3 | wulanhaote
# City not found. Skipping...
# Processing Record 28 of Set 3 | lerwick
# Processing Record 29 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 3 | pochutla
# Processing Record 31 of Set 3 | ulladulla
# Processing Record 32 of Set 3 | tabou
# Processing Record 33 of Set 3 | mabaruma
# Processing Record 34 of Set 3 | pisco
# Processing Record 35 of Set 3 | avarua
# Processing Record 36 of Set 3 | san quintin
# Processing Record 37 of Set 3 | tidore
# City not found. Skipping...
# Processing Record 38 of Set 3 | longyearbyen
# Processing Record 39 of Set 3 | krasnoselkup
# Processing Record 40 of Set 3 | tiksi
# Processing Record 41 of Set 3 | socorro
# Processing Record 42 of Set 3 | ceyhan
# Processing Record 43 of Set 3 | salalah
# Processing Record 44 of Set 3 | ostersund
# Processing Record 45 of Set 3 | okhotsk
# Processing Record 46 of Set 3 | touros
# Processing Record 47 of Set 3 | hambantota
# Processing Record 48 of Set 3 | norman wells
# Processing Record 49 of Set 3 | san luis
# Processing Record 50 of Set 3 | arraial do cabo
# Processing Record 1 of Set 4 | port blair
# Processing Record 2 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 4 | gornet
# Processing Record 4 of Set 4 | orissaare
# Processing Record 5 of Set 4 | lokosovo
# Processing Record 6 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 7 of Set 4 | port-gentil
# Processing Record 8 of Set 4 | murzzuschlag
# Processing Record 9 of Set 4 | nantucket
# Processing Record 10 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 11 of Set 4 | bam
# Processing Record 12 of Set 4 | ponta do sol
# Processing Record 13 of Set 4 | geraldton
# Processing Record 14 of Set 4 | saskatoon
# Processing Record 15 of Set 4 | kinablangan
# Processing Record 16 of Set 4 | nadym
# Processing Record 17 of Set 4 | nueva loja
# Processing Record 18 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 4 | vardo
# Processing Record 20 of Set 4 | tierralta
# Processing Record 21 of Set 4 | batsfjord
# Processing Record 22 of Set 4 | raudeberg
# Processing Record 23 of Set 4 | xuddur
# Processing Record 24 of Set 4 | hamilton
# Processing Record 25 of Set 4 | oranjemund
# Processing Record 26 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 27 of Set 4 | millau
# Processing Record 28 of Set 4 | rumboci
# Processing Record 29 of Set 4 | pevek
# Processing Record 30 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 4 | kruisfontein
# Processing Record 32 of Set 4 | westport
# Processing Record 33 of Set 4 | shimoda
# Processing Record 34 of Set 4 | mar del plata
# Processing Record 35 of Set 4 | riyadh
# Processing Record 36 of Set 4 | la romana
# Processing Record 37 of Set 4 | port macquarie
# Processing Record 38 of Set 4 | abha
# Processing Record 39 of Set 4 | shitanjing
# Processing Record 40 of Set 4 | novikovo
# Processing Record 41 of Set 4 | flinders
# Processing Record 42 of Set 4 | vallenar
# Processing Record 43 of Set 4 | georgetown
# Processing Record 44 of Set 4 | daxian
# City not found. Skipping...
# Processing Record 45 of Set 4 | palembang
# Processing Record 46 of Set 4 | saint george
# Processing Record 47 of Set 4 | talnakh
# Processing Record 48 of Set 4 | kalyazin
# Processing Record 49 of Set 4 | bathsheba
# Processing Record 50 of Set 4 | forestville
# Processing Record 1 of Set 5 | brigantine
# Processing Record 2 of Set 5 | dvinskoy
# Processing Record 3 of Set 5 | iqaluit
# Processing Record 4 of Set 5 | surt
# Processing Record 5 of Set 5 | ostrovnoy
# Processing Record 6 of Set 5 | sistranda
# Processing Record 7 of Set 5 | severo-kurilsk
# Processing Record 8 of Set 5 | puerto narino
# Processing Record 9 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 5 | santa rita
# Processing Record 11 of Set 5 | livingston
# Processing Record 12 of Set 5 | souillac
# Processing Record 13 of Set 5 | sur
# Processing Record 14 of Set 5 | arcata
# Processing Record 15 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 16 of Set 5 | ramshir
# Processing Record 17 of Set 5 | iquitos
# Processing Record 18 of Set 5 | ullapool
# Processing Record 19 of Set 5 | barinas
# Processing Record 20 of Set 5 | bay roberts
# Processing Record 21 of Set 5 | salt
# Processing Record 22 of Set 5 | alihe
# Processing Record 23 of Set 5 | beira
# Processing Record 24 of Set 5 | new norfolk
# Processing Record 25 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 26 of Set 5 | ust-omchug
# Processing Record 27 of Set 5 | iseyin
# Processing Record 28 of Set 5 | biak
# Processing Record 29 of Set 5 | albany
# Processing Record 30 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 5 | harper
# Processing Record 32 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 33 of Set 5 | santa maria
# Processing Record 34 of Set 5 | chulman
# Processing Record 35 of Set 5 | severobaykalsk
# Processing Record 36 of Set 5 | ribeira grande
# Processing Record 37 of Set 5 | olafsvik
# Processing Record 38 of Set 5 | sao joao da barra
# Processing Record 39 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 5 | guerrero negro
# Processing Record 41 of Set 5 | mahebourg
# Processing Record 42 of Set 5 | constantine
# Processing Record 43 of Set 5 | belmonte
# Processing Record 44 of Set 5 | makakilo city
# Processing Record 45 of Set 5 | hearst
# Processing Record 46 of Set 5 | nizhniy kuranakh
# Processing Record 47 of Set 5 | necochea
# Processing Record 48 of Set 5 | promyshlennyy
# Processing Record 49 of Set 5 | batan
# Processing Record 50 of Set 5 | margarita
# Processing Record 1 of Set 6 | vzmorye
# Processing Record 2 of Set 6 | faanui
# Processing Record 3 of Set 6 | nemuro
# Processing Record 4 of Set 6 | axim
# Processing Record 5 of Set 6 | broken hill
# Processing Record 6 of Set 6 | cervo
# Processing Record 7 of Set 6 | saint-pierre
# Processing Record 8 of Set 6 | nador
# Processing Record 9 of Set 6 | poya
# Processing Record 10 of Set 6 | mallapuram
# Processing Record 11 of Set 6 | avera
# Processing Record 12 of Set 6 | corning
# Processing Record 13 of Set 6 | atar
# Processing Record 14 of Set 6 | kuteynykove
# Processing Record 15 of Set 6 | barroualie
# City not found. Skipping...
# Processing Record 16 of Set 6 | lata
# Processing Record 17 of Set 6 | codrington
# Processing Record 18 of Set 6 | puerto leguizamo
# Processing Record 19 of Set 6 | nome
# Processing Record 20 of Set 6 | huarmey
# Processing Record 21 of Set 6 | bilma
# Processing Record 22 of Set 6 | sitka
# Processing Record 23 of Set 6 | buchanan
# Processing Record 24 of Set 6 | pathanamthitta
# Processing Record 25 of Set 6 | mungwi
# Processing Record 26 of Set 6 | rondonopolis
# Processing Record 27 of Set 6 | half moon bay
# Processing Record 28 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 6 | margate
# Processing Record 30 of Set 6 | atocha
# Processing Record 31 of Set 6 | tilichiki
# Processing Record 32 of Set 6 | zhireken
# Processing Record 33 of Set 6 | rocha
# Processing Record 34 of Set 6 | sinegorye
# Processing Record 35 of Set 6 | griffith
# Processing Record 36 of Set 6 | acarau
# Processing Record 37 of Set 6 | manokwari
# Processing Record 38 of Set 6 | henties bay
# Processing Record 39 of Set 6 | kholodnyy
# Processing Record 40 of Set 6 | kearney
# Processing Record 41 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 6 | waipawa
# Processing Record 43 of Set 6 | karpathos
# Processing Record 44 of Set 6 | grindavik
# Processing Record 45 of Set 6 | rioja
# Processing Record 46 of Set 6 | sakakah
# Processing Record 47 of Set 6 | tutoia
# Processing Record 48 of Set 6 | yomou
# Processing Record 49 of Set 6 | tahta
# Processing Record 50 of Set 6 | castro
# Processing Record 1 of Set 7 | abu dhabi
# Processing Record 2 of Set 7 | locri
# Processing Record 3 of Set 7 | ribeira brava
# Processing Record 4 of Set 7 | kabelvag
# Processing Record 5 of Set 7 | constitucion
# Processing Record 6 of Set 7 | mayya
# Processing Record 7 of Set 7 | thompson
# Processing Record 8 of Set 7 | chaoyang
# Processing Record 9 of Set 7 | conde
# Processing Record 10 of Set 7 | ijaki
# City not found. Skipping...
# Processing Record 11 of Set 7 | vitim
# Processing Record 12 of Set 7 | umm lajj
# Processing Record 13 of Set 7 | saint-augustin
# Processing Record 14 of Set 7 | pangnirtung
# Processing Record 15 of Set 7 | adrar
# Processing Record 16 of Set 7 | esperance
# Processing Record 17 of Set 7 | puerto el triunfo
# Processing Record 18 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 19 of Set 7 | te anau
# Processing Record 20 of Set 7 | dzheyrakh
# Processing Record 21 of Set 7 | astaneh-ye ashrafiyeh
# Processing Record 22 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 23 of Set 7 | comodoro rivadavia
# Processing Record 24 of Set 7 | faya
# Processing Record 25 of Set 7 | mahadday weyne
# City not found. Skipping...
# Processing Record 26 of Set 7 | cidreira
# Processing Record 27 of Set 7 | pueblo nuevo
# Processing Record 28 of Set 7 | kango
# Processing Record 29 of Set 7 | vostok
# Processing Record 30 of Set 7 | los llanos de aridane
# Processing Record 31 of Set 7 | anamur
# Processing Record 32 of Set 7 | cabo san lucas
# Processing Record 33 of Set 7 | ust-kuyga
# Processing Record 34 of Set 7 | sisimiut
# Processing Record 35 of Set 7 | cabedelo
# Processing Record 36 of Set 7 | hasaki
# Processing Record 37 of Set 7 | puerto carreno
# Processing Record 38 of Set 7 | cedar city
# Processing Record 39 of Set 7 | laguna
# Processing Record 40 of Set 7 | waingapu
# Processing Record 41 of Set 7 | mlimba
# Processing Record 42 of Set 7 | san cristobal
# Processing Record 43 of Set 7 | ossora
# Processing Record 44 of Set 7 | nanortalik
# Processing Record 45 of Set 7 | ladario
# Processing Record 46 of Set 7 | balikpapan
# Processing Record 47 of Set 7 | camacha
# Processing Record 48 of Set 7 | shieli
# Processing Record 49 of Set 7 | chiredzi
# Processing Record 50 of Set 7 | roma
# Processing Record 1 of Set 8 | bilkha
# Processing Record 2 of Set 8 | gardez
# Processing Record 3 of Set 8 | padang
# Processing Record 4 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 5 of Set 8 | englewood
# Processing Record 6 of Set 8 | tuatapere
# Processing Record 7 of Set 8 | batemans bay
# Processing Record 8 of Set 8 | bellevue
# Processing Record 9 of Set 8 | mossendjo
# Processing Record 10 of Set 8 | quang ngai
# Processing Record 11 of Set 8 | beloha
# Processing Record 12 of Set 8 | harrai
# Processing Record 13 of Set 8 | pitimbu
# Processing Record 14 of Set 8 | grand forks
# Processing Record 15 of Set 8 | isangel
# Processing Record 16 of Set 8 | ayan
# Processing Record 17 of Set 8 | libreville
# Processing Record 18 of Set 8 | metu
# Processing Record 19 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 20 of Set 8 | meylan
# Processing Record 21 of Set 8 | zhezkazgan
# Processing Record 22 of Set 8 | severnyy
# Processing Record 23 of Set 8 | mareeba
# Processing Record 24 of Set 8 | bonavista
# Processing Record 25 of Set 8 | santa cruz del sur
# Processing Record 26 of Set 8 | mecca
# Processing Record 27 of Set 8 | nogent-le-rotrou
# Processing Record 28 of Set 8 | lagoa
# Processing Record 29 of Set 8 | bowen
# Processing Record 30 of Set 8 | horki
# Processing Record 31 of Set 8 | bubaque
# Processing Record 32 of Set 8 | taltal
# Processing Record 33 of Set 8 | berdigestyakh
# Processing Record 34 of Set 8 | luanda
# Processing Record 35 of Set 8 | ambalavao
# Processing Record 36 of Set 8 | kjollefjord
# Processing Record 37 of Set 8 | ask
# Processing Record 38 of Set 8 | casper
# Processing Record 39 of Set 8 | kahului
# Processing Record 40 of Set 8 | san jose
# Processing Record 41 of Set 8 | daru
# Processing Record 42 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 43 of Set 8 | valparaiso
# Processing Record 44 of Set 8 | saldanha
# Processing Record 45 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 8 | kieta
# Processing Record 47 of Set 8 | seoul
# Processing Record 48 of Set 8 | kununurra
# Processing Record 49 of Set 8 | istisu
# Processing Record 50 of Set 8 | polunochnoye
# Processing Record 1 of Set 9 | camocim
# Processing Record 2 of Set 9 | kernersville
# Processing Record 3 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 4 of Set 9 | fort nelson
# Processing Record 5 of Set 9 | meulaboh
# Processing Record 6 of Set 9 | karakol
# Processing Record 7 of Set 9 | yuzhno-sukhokumsk
# Processing Record 8 of Set 9 | sao felix do xingu
# Processing Record 9 of Set 9 | luderitz
# Processing Record 10 of Set 9 | sorland
# Processing Record 11 of Set 9 | sabha
# Processing Record 12 of Set 9 | panaba
# Processing Record 13 of Set 9 | nishihara
# Processing Record 14 of Set 9 | hurghada
# Processing Record 15 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 9 | gollere
# City not found. Skipping...
# Processing Record 17 of Set 9 | grindsted
# Processing Record 18 of Set 9 | quatre cocos
# Processing Record 19 of Set 9 | knoxville
# Processing Record 20 of Set 9 | derzhavinsk
# Processing Record 21 of Set 9 | erenhot
# Processing Record 22 of Set 9 | tevaitoa
# Processing Record 23 of Set 9 | bud
# Processing Record 24 of Set 9 | oksfjord
# Processing Record 25 of Set 9 | auki
# Processing Record 26 of Set 9 | saint-ambroise
# Processing Record 27 of Set 9 | portoferraio
# Processing Record 28 of Set 9 | ipu
# Processing Record 29 of Set 9 | sandwick
# Processing Record 30 of Set 9 | tura
# Processing Record 31 of Set 9 | la ronge
# Processing Record 32 of Set 9 | tessalit
# Processing Record 33 of Set 9 | caravelas
# Processing Record 34 of Set 9 | peniche
# Processing Record 35 of Set 9 | karacakoy
# Processing Record 36 of Set 9 | malanje
# Processing Record 37 of Set 9 | malaya purga
# Processing Record 38 of Set 9 | payson
# Processing Record 39 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 40 of Set 9 | magadan
# Processing Record 41 of Set 9 | sola
# Processing Record 42 of Set 9 | pontianak
# Processing Record 43 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 44 of Set 9 | batagay
# Processing Record 45 of Set 9 | taburi
# City not found. Skipping...
# Processing Record 46 of Set 9 | vila velha
# Processing Record 47 of Set 9 | vanino
# Processing Record 48 of Set 9 | ahipara
# Processing Record 49 of Set 9 | road town
# Processing Record 50 of Set 9 | birao
# Processing Record 1 of Set 10 | ojiya
# Processing Record 2 of Set 10 | kita
# Processing Record 3 of Set 10 | menongue
# Processing Record 4 of Set 10 | puerto del rosario
# Processing Record 5 of Set 10 | zabol
# Processing Record 6 of Set 10 | namibe
# Processing Record 7 of Set 10 | roald
# Processing Record 8 of Set 10 | bang saphan
# Processing Record 9 of Set 10 | guane
# Processing Record 10 of Set 10 | takoradi
# Processing Record 11 of Set 10 | santa adelia
# Processing Record 12 of Set 10 | kasongo-lunda
# Processing Record 13 of Set 10 | ixtapa
# Processing Record 14 of Set 10 | samarai
# Processing Record 15 of Set 10 | chanute
# Processing Record 16 of Set 10 | talaja
# Processing Record 17 of Set 10 | manzil tamim
# City not found. Skipping...
# Processing Record 18 of Set 10 | balkhash
# Processing Record 19 of Set 10 | moen
# Processing Record 20 of Set 10 | boyolangu
# Processing Record 21 of Set 10 | dubbo
# Processing Record 22 of Set 10 | casablanca
# Processing Record 23 of Set 10 | korla
# Processing Record 24 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 25 of Set 10 | camajuani
# Processing Record 26 of Set 10 | port hardy
# Processing Record 27 of Set 10 | tyukalinsk
# Processing Record 28 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 29 of Set 10 | san lorenzo
# Processing Record 30 of Set 10 | el uvito
# Processing Record 31 of Set 10 | sokoto
# Processing Record 32 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 33 of Set 10 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 34 of Set 10 | damaturu
# Processing Record 35 of Set 10 | erzin
# Processing Record 36 of Set 10 | clyde river
# Processing Record 37 of Set 10 | evensk
# Processing Record 38 of Set 10 | randolph
# Processing Record 39 of Set 10 | kazuno
# Processing Record 40 of Set 10 | katsuura
# Processing Record 41 of Set 10 | maragogi
# Processing Record 42 of Set 10 | zapolyarnyy
# Processing Record 43 of Set 10 | praya
# Processing Record 44 of Set 10 | ilulissat
# Processing Record 45 of Set 10 | miri
# Processing Record 46 of Set 10 | antalaha
# Processing Record 47 of Set 10 | khandyga
# Processing Record 48 of Set 10 | chardara
# Processing Record 49 of Set 10 | koulikoro
# Processing Record 50 of Set 10 | rapid valley
# Processing Record 1 of Set 11 | amga
# Processing Record 2 of Set 11 | vidisha
# Processing Record 3 of Set 11 | saint anthony
# Processing Record 4 of Set 11 | mbalmayo
# Processing Record 5 of Set 11 | coihaique
# Processing Record 6 of Set 11 | kharp
# Processing Record 7 of Set 11 | goure
# Processing Record 8 of Set 11 | yuma
# Processing Record 9 of Set 11 | usinsk
# Processing Record 10 of Set 11 | nizwa
# Processing Record 11 of Set 11 | bassar
# Processing Record 12 of Set 11 | hami
# Processing Record 13 of Set 11 | tiznit
# Processing Record 14 of Set 11 | dzhebariki-khaya
# Processing Record 15 of Set 11 | deputatskiy
# Processing Record 16 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 17 of Set 11 | srednekolymsk
# Processing Record 18 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 19 of Set 11 | navalgund
# Processing Record 20 of Set 11 | barreirinha
# Processing Record 21 of Set 11 | baghdad
# Processing Record 22 of Set 11 | thinadhoo
# Processing Record 23 of Set 11 | labuan
# Processing Record 24 of Set 11 | koulamoutou
# Processing Record 25 of Set 11 | charters towers
# Processing Record 26 of Set 11 | santarem
# Processing Record 27 of Set 11 | yoichi
# Processing Record 28 of Set 11 | ngunguru
# Processing Record 29 of Set 11 | jinxiang
# Processing Record 30 of Set 11 | venado tuerto
# Processing Record 31 of Set 11 | delmas
# Processing Record 32 of Set 11 | mehamn
# Processing Record 33 of Set 11 | kavaratti
# Processing Record 34 of Set 11 | hutchinson
# Processing Record 35 of Set 11 | svetlyy
# Processing Record 36 of Set 11 | santiago del estero
# Processing Record 37 of Set 11 | payo
# Processing Record 38 of Set 11 | birjand
# Processing Record 39 of Set 11 | cayenne
# Processing Record 40 of Set 11 | dingle
# Processing Record 41 of Set 11 | narrabri
# Processing Record 42 of Set 11 | kibala
# Processing Record 43 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 11 | xai-xai
# Processing Record 45 of Set 11 | sobolevo
# Processing Record 46 of Set 11 | yerbogachen
# Processing Record 47 of Set 11 | tigil
# Processing Record 48 of Set 11 | amot
# Processing Record 49 of Set 11 | selenduma
# Processing Record 50 of Set 11 | lompoc
# Processing Record 1 of Set 12 | tambura
# Processing Record 2 of Set 12 | iskateley
# Processing Record 3 of Set 12 | portland
# Processing Record 4 of Set 12 | mount gambier
# Processing Record 5 of Set 12 | mount vernon
# Processing Record 6 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 7 of Set 12 | wonthaggi
# Processing Record 8 of Set 12 | ningan
# City not found. Skipping...
# Processing Record 9 of Set 12 | fairbanks
# Processing Record 10 of Set 12 | idritsa
# Processing Record 11 of Set 12 | skelleftea
# Processing Record 12 of Set 12 | tomatlan
# Processing Record 13 of Set 12 | ituni
# City not found. Skipping...
# Processing Record 14 of Set 12 | kysyl-syr
# Processing Record 15 of Set 12 | gat
# Processing Record 16 of Set 12 | hazorasp
# Processing Record 17 of Set 12 | whyalla
# Processing Record 18 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 19 of Set 12 | coquimbo
# Processing Record 20 of Set 12 | sinnamary
# Processing Record 21 of Set 12 | ribas do rio pardo
# Processing Record 22 of Set 12 | arys
# Processing Record 23 of Set 12 | shibetsu
# Processing Record 24 of Set 12 | salinas
# Processing Record 25 of Set 12 | lorengau
# Processing Record 26 of Set 12 | fonte boa
# Processing Record 27 of Set 12 | skoghall
# Processing Record 28 of Set 12 | streator
# Processing Record 29 of Set 12 | lavrentiya
# Processing Record 30 of Set 12 | seda
# Processing Record 31 of Set 12 | macae
# Processing Record 32 of Set 12 | goya
# Processing Record 33 of Set 12 | stromness
# Processing Record 34 of Set 12 | alexandria
# Processing Record 35 of Set 12 | goderich
# Processing Record 36 of Set 12 | dekalb
# Processing Record 37 of Set 12 | thetford mines
# Processing Record 38 of Set 12 | soligalich
# Processing Record 39 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 12 | mount isa
# Processing Record 41 of Set 12 | luoyang
# Processing Record 42 of Set 12 | tamiahua
# Processing Record 43 of Set 12 | la palma
# Processing Record 44 of Set 12 | briancon
# Processing Record 45 of Set 12 | whitehorse
# Processing Record 46 of Set 12 | san vicente
# Processing Record 47 of Set 12 | kerrville
# Processing Record 48 of Set 12 | porbandar
# Processing Record 49 of Set 12 | baykit
# Processing Record 50 of Set 12 | male
# Processing Record 1 of Set 13 | aguimes
# Processing Record 2 of Set 13 | yafran
# Processing Record 3 of Set 13 | narsaq
# Processing Record 4 of Set 13 | tartagal
# Processing Record 5 of Set 13 | bom jesus
# Processing Record 6 of Set 13 | toftir
# City not found. Skipping...
# Processing Record 7 of Set 13 | kaoma
# Processing Record 8 of Set 13 | bentiu
# Processing Record 9 of Set 13 | puerto escondido
# Processing Record 10 of Set 13 | emba
# Processing Record 11 of Set 13 | mayor pablo lagerenza
# Processing Record 12 of Set 13 | nabire
# Processing Record 13 of Set 13 | xining
# Processing Record 14 of Set 13 | yumen
# Processing Record 15 of Set 13 | kalianget
# Processing Record 16 of Set 13 | houston
# Processing Record 17 of Set 13 | lakatoro
# Processing Record 18 of Set 13 | aklavik
# Processing Record 19 of Set 13 | caloundra
# Processing Record 20 of Set 13 | turangi
# Processing Record 21 of Set 13 | merritt
# Processing Record 22 of Set 13 | rostock
# Processing Record 23 of Set 13 | kailua
# Processing Record 24 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 25 of Set 13 | parelhas
# Processing Record 26 of Set 13 | tukrah
# Processing Record 27 of Set 13 | vaitape
# Processing Record 28 of Set 13 | turukhansk
# Processing Record 29 of Set 13 | balakhta
# Processing Record 30 of Set 13 | solwezi
# Processing Record 31 of Set 13 | chokurdakh
# Processing Record 32 of Set 13 | atambua
# Processing Record 33 of Set 13 | chipinge
# Processing Record 34 of Set 13 | whakatane
# Processing Record 35 of Set 13 | aksay
# Processing Record 36 of Set 13 | noumea
# Processing Record 37 of Set 13 | christchurch
# Processing Record 38 of Set 13 | zvenyhorodka
# Processing Record 39 of Set 13 | houma
# Processing Record 40 of Set 13 | itarema
# Processing Record 41 of Set 13 | khuzdar
# Processing Record 42 of Set 13 | manta
# Processing Record 43 of Set 13 | qasigiannguit
# Processing Record 44 of Set 13 | corn island
# Processing Record 45 of Set 13 | arona
# Processing Record 46 of Set 13 | krasnyy chikoy
# Processing Record 47 of Set 13 | la belleza
# Processing Record 48 of Set 13 | haines junction
# Processing Record 49 of Set 13 | kabala
# Processing Record 50 of Set 13 | camopi
# Processing Record 1 of Set 14 | lubango
# Processing Record 2 of Set 14 | hualmay
# Processing Record 3 of Set 14 | kharan
# Processing Record 4 of Set 14 | pleasant point
# Processing Record 5 of Set 14 | kautokeino
# Processing Record 6 of Set 14 | gambo
# Processing Record 7 of Set 14 | ust-tsilma
# Processing Record 8 of Set 14 | mercedes
# Processing Record 9 of Set 14 | melfi
# Processing Record 10 of Set 14 | cairns
# Processing Record 11 of Set 14 | nizhnevartovsk
# Processing Record 12 of Set 14 | jardim
# Processing Record 13 of Set 14 | santa cruz
# Processing Record 14 of Set 14 | rio gallegos
# Processing Record 15 of Set 14 | corinto
# Processing Record 16 of Set 14 | green river
# Processing Record 17 of Set 14 | liusha
# Processing Record 18 of Set 14 | moerai
# Processing Record 19 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 20 of Set 14 | ganzhou
# Processing Record 21 of Set 14 | makaha
# Processing Record 22 of Set 14 | burica
# City not found. Skipping...
# Processing Record 23 of Set 14 | hobyo
# Processing Record 24 of Set 14 | mayo
# Processing Record 25 of Set 14 | port-cartier
# Processing Record 26 of Set 14 | ayagoz
# Processing Record 27 of Set 14 | san francisco del mar
# Processing Record 28 of Set 14 | neyshabur
# Processing Record 29 of Set 14 | ciras
# City not found. Skipping...
# Processing Record 30 of Set 14 | teguise
# Processing Record 31 of Set 14 | ouargaye
# Processing Record 32 of Set 14 | kapoeta
# Processing Record 33 of Set 14 | sulangan
# Processing Record 34 of Set 14 | kant
# Processing Record 35 of Set 14 | arlit
# Processing Record 36 of Set 14 | awjilah
# Processing Record 37 of Set 14 | mehran
# Processing Record 38 of Set 14 | scottsburgh
# City not found. Skipping...
# Processing Record 39 of Set 14 | sohag
# Processing Record 40 of Set 14 | malindi
# Processing Record 41 of Set 14 | virovitica
# Processing Record 42 of Set 14 | hofn
# Processing Record 43 of Set 14 | kyle
# Processing Record 44 of Set 14 | nushki
# Processing Record 45 of Set 14 | altamont
# Processing Record 46 of Set 14 | general roca
# Processing Record 47 of Set 14 | buta
# Processing Record 48 of Set 14 | koungou
# Processing Record 49 of Set 14 | sidi ali
# Processing Record 50 of Set 14 | rulenge
# Processing Record 1 of Set 15 | luwuk
# Processing Record 2 of Set 15 | solnechnyy
# Processing Record 3 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 4 of Set 15 | leninskoye
# Processing Record 5 of Set 15 | eregli
# Processing Record 6 of Set 15 | kupang
# Processing Record 7 of Set 15 | berlevag
# Processing Record 8 of Set 15 | west fargo
# Processing Record 9 of Set 15 | santa isabel do rio negro
# Processing Record 10 of Set 15 | greymouth
# Processing Record 11 of Set 15 | gondanglegi
# Processing Record 12 of Set 15 | blankenberge
# Processing Record 13 of Set 15 | puerto lempira
# Processing Record 14 of Set 15 | play cu
# City not found. Skipping...
# Processing Record 15 of Set 15 | lafayette
# Processing Record 16 of Set 15 | imperia
# Processing Record 17 of Set 15 | gazli
# Processing Record 18 of Set 15 | cartagena del chaira
# Processing Record 19 of Set 15 | klaksvik
# Processing Record 20 of Set 15 | lobito
# Processing Record 21 of Set 15 | hay river
# Processing Record 22 of Set 15 | college
# Processing Record 23 of Set 15 | stornoway
# Processing Record 24 of Set 15 | mayumba
# Processing Record 25 of Set 15 | wagar
# Processing Record 26 of Set 15 | geilo
# Processing Record 27 of Set 15 | outjo
# Processing Record 28 of Set 15 | salzburg
# Processing Record 29 of Set 15 | zhigansk
# Processing Record 30 of Set 15 | nyzhnya duvanka
# Processing Record 31 of Set 15 | kutum
# Processing Record 32 of Set 15 | grand gaube
# Processing Record 33 of Set 15 | bayir
# Processing Record 34 of Set 15 | kamaishi
# Processing Record 35 of Set 15 | rawson
# Processing Record 36 of Set 15 | pajan
# Processing Record 37 of Set 15 | ulaangom
# Processing Record 38 of Set 15 | gornopravdinsk
# Processing Record 39 of Set 15 | mosjoen
# Processing Record 40 of Set 15 | amapa
# Processing Record 41 of Set 15 | saint-leu
# Processing Record 42 of Set 15 | grand-santi
# Processing Record 43 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 44 of Set 15 | vung tau
# Processing Record 45 of Set 15 | mitsamiouli
# Processing Record 46 of Set 15 | pitiquito
# Processing Record 47 of Set 15 | bilibino
# Processing Record 48 of Set 15 | toyooka
# Processing Record 49 of Set 15 | timmins
# Processing Record 50 of Set 15 | maputo
# Processing Record 1 of Set 16 | sheridan
# Processing Record 2 of Set 16 | zhicheng
# Processing Record 3 of Set 16 | troitskoye
# Processing Record 4 of Set 16 | brae
# Processing Record 5 of Set 16 | emerald
# Processing Record 6 of Set 16 | davila
# Processing Record 7 of Set 16 | bom jesus da lapa
# Processing Record 8 of Set 16 | zhanaozen
# Processing Record 9 of Set 16 | bernburg
# Processing Record 10 of Set 16 | moyale
# Processing Record 11 of Set 16 | plouzane
# Processing Record 12 of Set 16 | muscat
# Processing Record 13 of Set 16 | sorong
# Processing Record 14 of Set 16 | buariki
# City not found. Skipping...
# Processing Record 15 of Set 16 | trat
# Processing Record 16 of Set 16 | barrhead
# Processing Record 17 of Set 16 | bairnsdale
# Processing Record 18 of Set 16 | shizunai
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 700

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                Bluff -46.6000  168.3333     57.11        77          62
# 1         Punta Arenas -53.1500  -70.9167     42.91        70           0
# 2          Yellowknife  62.4560 -114.3525     40.41       100          90
# 3              Tarakan   3.3000  117.6333     80.10        89          75
# 4              Dunedin -45.8742  170.5036     57.56        81          62
# 5        Santo Domingo  18.5001  -69.9886     74.88        83           5
# 6  Ostrow Wielkopolski  51.6550   17.8069     49.60        90         100
# 7          Port Alfred -33.5906   26.8910     66.92        85         100
# 8          Krasnyy Yar  46.5331   48.3456     39.13        72           6
# 9              Rikitea -23.1203 -134.9692     74.53        84         100
#
#    Wind Speed Country      Description                 Date
# 0        0.65      NZ    broken clouds  2021-10-27 01:12:45
# 1       14.97      CL        clear sky  2021-10-27 01:11:17
# 2        4.61      CA       light rain  2021-10-27 01:12:46
# 3        3.44      ID    broken clouds  2021-10-27 01:12:47
# 4        4.72      NZ    broken clouds  2021-10-27 01:12:47
# 5        2.35      DO        clear sky  2021-10-27 01:11:04
# 6        8.21      PL  overcast clouds  2021-10-27 01:12:48
# 7       28.52      ZA  overcast clouds  2021-10-27 01:12:48
# 8        1.74      RU        clear sky  2021-10-27 01:12:48
# 9       13.56      PF    moderate rain  2021-10-27 01:12:49

# %%
city_data_df = city_data_df.reindex(columns = ["City" , "Country" , "Lat" , "Lng" , "Max Temp" , "Humidity" , "Cloudiness" , "Wind Speed" , "Description" , "Date"])
city_data_df.head(10)
# Out:
#                   City Country      Lat       Lng  Max Temp  Humidity  \
# 0                Bluff      NZ -46.6000  168.3333     57.11        77
# 1         Punta Arenas      CL -53.1500  -70.9167     42.91        70
# 2          Yellowknife      CA  62.4560 -114.3525     40.41       100
# 3              Tarakan      ID   3.3000  117.6333     80.10        89
# 4              Dunedin      NZ -45.8742  170.5036     57.56        81
# 5        Santo Domingo      DO  18.5001  -69.9886     74.88        83
# 6  Ostrow Wielkopolski      PL  51.6550   17.8069     49.60        90
# 7          Port Alfred      ZA -33.5906   26.8910     66.92        85
# 8          Krasnyy Yar      RU  46.5331   48.3456     39.13        72
# 9              Rikitea      PF -23.1203 -134.9692     74.53        84
#
#    Cloudiness  Wind Speed      Description                 Date
# 0          62        0.65    broken clouds  2021-10-27 01:12:45
# 1           0       14.97        clear sky  2021-10-27 01:11:17
# 2          90        4.61       light rain  2021-10-27 01:12:46
# 3          75        3.44    broken clouds  2021-10-27 01:12:47
# 4          62        4.72    broken clouds  2021-10-27 01:12:47
# 5           5        2.35        clear sky  2021-10-27 01:11:04
# 6         100        8.21  overcast clouds  2021-10-27 01:12:48
# 7         100       28.52  overcast clouds  2021-10-27 01:12:48
# 8           6        1.74        clear sky  2021-10-27 01:12:48
# 9         100       13.56    moderate rain  2021-10-27 01:12:49

# %%
#create an output file in CSV 
import os
output_data_file = os.path.join("vacation_search" , "weatherPy_vacation.csv")
#export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label = "city_ID")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ee677998005f> in <module>
#       3 output_data_file = os.path.join("vacation_search" , "weatherPy_vacation.csv")
#       4 #export the city_data into a csv
# ----> 5 city_data_df.to_csv(output_data_file, index_label = "city_ID")
#
# NameError: name 'city_data_df' is not defined
